# %% [markdown]
# # Grain Size Distribution - Height Correlation Function
#
# Find relevant parameters describing the topography of sputtered Ruthenium thin films on Si substrate
#
# How:
# - Roughness RMS
# - Fit exponential increase
# - Take intersection between RMS asymptote and Fit
#
# Output parameters:
# - Roughness
# - Correlation Length
# - Alpha exponent
#
# Note: here I am using the images which have their contrast adjusted. For reference:
# http://homepages.inf.ed.ac.uk/rbf/HIPR2/stretch.htm

# %%
import os
import sys
import json

import numpy as np
import pandas as pd
import pickle

# %matplotlib nbagg
# %reload_ext autoreload
# %autoreload 2
import matplotlib
import matplotlib.lines as mlines
import matplotlib.pyplot as plt

from matplotlib import cm
from skimage import data, io, exposure, img_as_float

from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter

# %%
debug = True #or 'False' when you do not want to debug

path = "/Users/sfiligoj/Desktop/SEM_all_contrasted_corrected/"
os.chdir(path)
filess = os.listdir()
filess = [f for f in filess if (f.endswith('tif') and '*' not in f)]
print(f"Found {len(filess)} files")
# Out:
# Found 151 files

# %%
# read-in the dictionary of Scan Size values:
# (see Manual Reading FOV file)
with open('FOVs.json', 'r') as f:
    FOV_dict = json.loads(f.read())

# %%
reference = io.imread('Ru_LH_700C_075.tif', as_gray=True)
reference = img_as_float(reference[:1024,:])
# We create the empty DataFrame:
df = pd.DataFrame(
        columns= ['filename', 'density', 'temp', 'hhcorr', 'scansize', 'n_pix'])

for i,file in enumerate(filess[:]):
    print(f'running file: {i}')
    
    # Parse information from filename
    if 'L_' in file:
        density = 'L'
        if 'asdep' in file:
            temperature = '25'
        else:
            temperature = file[2:5]
        
    if 'H_' in file:
        density = 'H'
        if 'asdep' in file:
            temperature = '25'
        else:
            temperature = file[2:5]

    if 'Ru_LH' in file:
        density = 'LH'
        if 'asdep' in file:
            temperature = '25'
        else:
            temperature = file[6:9]
    
    print(f'density: {density} and temperature {temperature}')

    img = io.imread(file, as_gray = True)
    img = img_as_float(img[:1024,:])
    
    
    # Contrast correction:   
    img = exposure.match_histograms(img, reference)
    
    # Fixed parameters:  
    N_Pixel = img.shape[0]                              # before was len(data), which works in this case, but it would be the N of rows 
    ScanSize = FOV_dict[file]
    StepSize = ScanSize/N_Pixel                          # nm/px     
        
    Xdelta = np.linspace(StepSize, ScanSize, num=N_Pixel)
    
    
    # ***    Calculate Height-Height correlation function:   ***

    HHcorr = np.zeros(N_Pixel)
    for px_dist in range(0, N_Pixel-1):
        shifted_data = img[:,px_dist+1:]
        data_section = img[:,:-px_dist-1]
        difference = (data_section-shifted_data)**2
        HHcorr[px_dist] = np.mean(difference)
    # The last point of HHcorr is always 0, so we work around it:
    HHcorr[-1] = HHcorr[-2]
    
    df = df.append( 
            {'filename': file , 
             'density': density, 
             'temp': temperature, 
             'hhcorr': HHcorr , 
             'scansize': ScanSize , 
             'n_pix': N_Pixel, 
            },
            ignore_index=True)
# Out:
# running file: 0
# density: H and temperature 25
# running file: 1
# density: LH and temperature 500
# running file: 2
# density: LH and temperature 700
# running file: 3
# density: L and temperature 25
# running file: 4
# density: H and temperature 700
# running file: 5
# density: H and temperature 700
# running file: 6
# density: LH and temperature 700
# running file: 7
# density: L and temperature 25
# running file: 8
# density: LH and temperature 700
# running file: 9
# density: LH and temperature 500
# running file: 10
# density: L and temperature 700
# running file: 11
# density: H and temperature 25
# running file: 12
# density: LH and temperature 600
# running file: 13
# density: H and temperature 25
# running file: 14
# density: H and temperature 800
# running file: 15
# density: L and temperature 700
# running file: 16
# density: H and temperature 250
# running file: 17
# density: L and temperature 25
# running file: 18
# density: LH and temperature 800
# running file: 19
# density: H and temperature 700
# running file: 20
# density: LH and temperature 800
# running file: 21
# density: LH and temperature 700
# running file: 22
# density: H and temperature 250
# running file: 23
# density: L and temperature 25
# running file: 24
# density: L and temperature 700
# running file: 25
# density: L and temperature 700
# running file: 26
# density: H and temperature 25
# running file: 27
# density: LH and temperature 600
# running file: 28
# density: H and temperature 600
# running file: 29
# density: LH and temperature 500
# running file: 30
# density: L and temperature 700
# running file: 31
# density: L and temperature 25
# running file: 32
# density: H and temperature 700
# running file: 33
# density: LH and temperature 700
# running file: 34
# density: LH and temperature 500
# running file: 35
# density: L and temperature 800
# running file: 36
# density: LH and temperature 600
# running file: 37
# density: H and temperature 25
# running file: 38
# density: H and temperature 25
# running file: 39
# density: H and temperature 800
# running file: 40
# density: LH and temperature 700
# running file: 41
# density: L and temperature 25
# running file: 42
# density: H and temperature 800
# running file: 43
# density: H and temperature 700
# running file: 44
# density: H and temperature 800
# running file: 45
# density: L and temperature 25
# running file: 46
# density: LH and temperature 700
# running file: 47
# density: LH and temperature 500
# running file: 48
# density: H and temperature 25
# running file: 49
# density: H and temperature 500
# running file: 50
# density: H and temperature 500
# running file: 51
# density: L and temperature 600
# running file: 52
# density: L and temperature 25
# running file: 53
# density: L and temperature 700
# running file: 54
# density: H and temperature 600
# running file: 55
# density: L and temperature 600
# running file: 56
# density: H and temperature 500
# running file: 57
# density: LH and temperature 25
# running file: 58
# density: LH and temperature 25
# running file: 59
# density: H and temperature 600
# running file: 60
# density: L and temperature 600
# running file: 61
# density: LH and temperature 250
# running file: 62
# density: LH and temperature 250
# running file: 63
# density: H and temperature 600
# running file: 64
# density: L and temperature 600
# running file: 65
# density: LH and temperature 25
# running file: 66
# density: H and temperature 500
# running file: 67
# density: L and temperature 500
# running file: 68
# density: LH and temperature 25
# running file: 69
# density: L and temperature 600
# running file: 70
# density: L and temperature 800
# running file: 71
# density: L and temperature 800
# running file: 72
# density: L and temperature 600
# running file: 73
# density: L and temperature 500
# running file: 74
# density: L and temperature 500
# running file: 75
# density: LH and temperature 25
# running file: 76
# density: H and temperature 600
# running file: 77
# density: L and temperature 700
# running file: 78
# density: LH and temperature 25
# running file: 79
# density: L and temperature 500
# running file: 80
# density: H and temperature 600
# running file: 81
# density: L and temperature 800
# running file: 82
# density: H and temperature 250
# running file: 83
# density: L and temperature 700
# running file: 84
# density: H and temperature 700
# running file: 85
# density: H and temperature 250
# running file: 86
# density: H and temperature 700
# running file: 87
# density: H and temperature 250
# running file: 88
# density: L and temperature 800
# running file: 89
# density: H and temperature 600
# running file: 90
# density: H and temperature 500
# running file: 91
# density: H and temperature 700
# running file: 92
# density: H and temperature 250
# running file: 93
# density: L and temperature 700
# running file: 94
# density: L and temperature 800
# running file: 95
# density: H and temperature 250
# running file: 96
# density: H and temperature 600
# running file: 97
# density: H and temperature 500
# running file: 98
# density: LH and temperature 250
# running file: 99
# density: H and temperature 500
# running file: 100
# density: LH and temperature 250
# running file: 101
# density: LH and temperature 250
# running file: 102
# density: H and temperature 700
# running file: 103
# density: H and temperature 500
# running file: 104
# density: H and temperature 500
# running file: 105
# density: H and temperature 800
# running file: 106
# density: L and temperature 700
# running file: 107
# density: H and temperature 800
# running file: 108
# density: H and temperature 700
# running file: 109
# density: L and temperature 250
# running file: 110
# density: LH and temperature 700
# running file: 111
# density: LH and temperature 800
# running file: 112
# density: H and temperature 700
# running file: 113
# density: H and temperature 800
# running file: 114
# density: L and temperature 700
# running file: 115
# density: LH and temperature 700
# running file: 116
# density: LH and temperature 700
# running file: 117
# density: L and temperature 250
# running file: 118
# density: H and temperature 800
# running file: 119
# density: LH and temperature 700
# running file: 120
# density: L and temperature 250
# running file: 121
# density: LH and temperature 700
# running file: 122
# density: LH and temperature 700
# running file: 123
# density: LH and temperature 700
# running file: 124
# density: L and temperature 250
# running file: 125
# density: LH and temperature 700
# running file: 126
# density: L and temperature 700
# running file: 127
# density: H and temperature 25
# running file: 128
# density: LH and temperature 700
# running file: 129
# density: H and temperature 250
# running file: 130
# density: L and temperature 25
# running file: 131
# density: LH and temperature 700
# running file: 132
# density: LH and temperature 800
# running file: 133
# density: LH and temperature 800
# running file: 134
# density: LH and temperature 800
# running file: 135
# density: LH and temperature 700
# running file: 136
# density: LH and temperature 800
# running file: 137
# density: LH and temperature 700
# running file: 138
# density: H and temperature 250
# running file: 139
# density: LH and temperature 700
# running file: 140
# density: L and temperature 700
# running file: 141
# density: H and temperature 500
# running file: 142
# density: LH and temperature 600
# running file: 143
# density: LH and temperature 700
# running file: 144
# density: LH and temperature 800
# running file: 145
# density: LH and temperature 800
# running file: 146
# density: H and temperature 500
# running file: 147
# density: LH and temperature 800
# running file: 148
# density: LH and temperature 800
# running file: 149
# density: H and temperature 700
# running file: 150
# density: LH and temperature 600

# %%
# Save a dictionary into a pickle file.
pickle.dump(df, open( "save.p", "wb" ) )
df
# Out:
#                   filename density temp  \
# 0          H_asdep_006.tif       H   25
# 1       Ru_LH_500C_015.tif      LH  500
# 2       Ru_LH_700C_077.tif      LH  700
# 3          L_asdep_007.tif       L   25
# 4           H_700C_024.tif       H  700
# ..                     ...     ...  ...
# 146  H_500C_5000nm_032.tif       H  500
# 147     Ru_LH_800C_033.tif      LH  800
# 148     Ru_LH_800C_027.tif      LH  800
# 149    H_700C_10um_043.tif       H  700
# 150     Ru_LH_600C_016.tif      LH  600
#
#                                                 hhcorr scansize n_pix
# 0    [0.029532958133807113, 0.03172089640968673, 0....      345  1024
# 1    [0.01841470656196632, 0.02307507579548702, 0.0...      829  1024
# 2    [0.005772947324770799, 0.006301168366615295, 0...      414  1024
# 3    [0.04142936148330632, 0.04775319104077777, 0.0...    11800  1024
# 4    [0.02107438041374748, 0.02270302762767064, 0.0...      518  1024
# ..                                                 ...      ...   ...
# 146  [0.024703719096106684, 0.03423447114183298, 0....     6380  1024
# 147  [0.004526015936482241, 0.0059289094323921095, ...     1180  1024
# 148  [0.0038333631593081077, 0.0041651386865076065,...      345  1024
# 149  [0.036170526296200475, 0.0433645346340971, 0.0...    16600  1024
# 150  [0.02119137948155146, 0.023130760988761247, 0....      518  1024
#
# [151 rows x 6 columns]

# %%
import pandas_profiling
from pathlib import Path
profile = df.profile_report(title="SEMdata")
profile.to_file(output_file=Path("./SEMdata.html"))
